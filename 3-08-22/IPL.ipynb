# %%
import pandas as pd
df=pd.read_csv("IPL.csv")
print(df)
# Out:
#      Sl.NO.    PLAYERNAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
df.shape
# Out:
# (130, 26)

# %%
df.info
# Out:
# <bound method DataFrame.info of      Sl.NO.    PLAYERNAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
df.sample(10)
# Out:
#      Sl.NO.     PLAYERNAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 90       91       Saha, WP    2     IND  KKR+    W. Keeper      74       0
# 78       79   Pankaj Singh    2     IND  RCB+       Bowler       0       0
# 83       84  Pietersen, KP    2     ENG  RCB+      Batsman    6654       5
# 29       30       Gony, MS    2     IND  CSK+       Bowler       0       0
# 31       32     Harris, RJ    2     AUS   DC+       Bowler     199      46
# 89       90      Ryder, JD    2      NZ  RCB+   Allrounder    1269       5
# 99      100   Shoaib Malik    2     PAK    DD   Allrounder    1606      21
# 110     111   Taylor, LRPL    2      NZ  RCB+      Batsman    2742       2
# 24       25     Gambhir, G    2     IND   DD+      Batsman    3712       0
# 55       56         Lee, B    2     AUS  KXI+       Bowler    1451     310
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# ...

# %%
df.head()
# Out:
#    Sl.NO.    PLAYERNAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df.head(10)
# Out:
#    Sl.NO.     PLAYERNAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1    Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2   Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3    Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4      Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5   Badrinath, S    2     IND   CSK      Batsman      63       0
# 5       6     Bailey, GJ    2     AUS   CSK      Batsman       0       0
# 6       7      Balaji, L    2     IND  CSK+       Bowler      51      27
# 7       8  Bollinger, DE    2     AUS   CSK       Bowler      54      50
# 8       9       Botha, J    2      SA    RR   Allrounder      83      17
# 9      10    Boucher, MV    2      SA  RCB+    W. Keeper    5515       1
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# ...

# %%
df.tail()
# Out:
#      Sl.NO.    PLAYERNAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 125           0      0.00  ...  125.64       2       0     0    0.00  0.00
# 126        6814     75.78  ...   42.85       0       0     0    0.00  0.00
# 127        8051     87.58  ...  131.88      67     569    23   24.74  7.02
# 128         790     73.55  ...   91.67       1    1783    65   27.43  7.75
# 129         343     95.81  ...  122.22       0      99     2   49.50  9.00
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df.tail(20)
# Out:
#      Sl.NO.        PLAYERNAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  \
# 110     111      Taylor, LRPL    2      NZ   RCB+      Batsman    2742
# 111     112     Tendulkar, SR    3     IND     MI      Batsman   15470
# 112     113        Tiwary, MK    2     IND    DD+      Batsman       0
# 113     114        Tiwary, SS    1     IND    MI+      Batsman       0
# 114     115          Tyagi, S    1     IND    CSK       Bowler       0
# 115     116          Umar Gul    2     PAK    KKR       Bowler     541
# 116     117       Uthappa, RV    2     IND   RCB+      Batsman       0
# 117     118       Vaas, WPUJC    3      SL     DC       Bowler    3089
# 118     119     Van der Merwe    2      SA   RCB+   Allrounder       0
# 119     120  Venugopal Rao, Y    2     IND    DC+      Batsman       0
# 120     121       Vettori, DL    2      NZ    DD+   Allrounder    4486
# 121     122    Vinay Kumar, R    2     IND   RCB+       Bowler      11
# ...

# %%
list(df.columns)
# Out:
# ['Sl.NO.',
#  'PLAYERNAME',
#  'AGE',
#  'COUNTRY',
#  'TEAM',
#  'PLAYING ROLE',
#  'T-RUNS',
#  'T-WKTS',
#  'ODI-RUNS-S',
#  'ODI-SR-B',
#  'ODI-WKTS',
#  'ODI-SR-BL',
#  'CAPTAINCY EXP',
#  'RUNS-S',
#  'HS',
#  'AVE',
#  'SR-B',
#  'SIXERS',
#  'RUNS-C',
#  'WKTS',
#  'AVE-BL',
#  'ECON',
#  'SR-BL',
#  'AUCTION YEAR',
#  'BASE PRICE',
#  'SOLD PRICE']

# %%
df.head(5).transpose()
# Out:
#                          0             1            2          3             4
# Sl.NO.                   1             2            3          4             5
# PLAYERNAME     Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R  Badrinath, S
# AGE                      2             2            2          1             2
# COUNTRY                 SA           BAN          IND        IND           IND
# TEAM                  KXIP           RCB          KKR        CSK           CSK
# PLAYING ROLE    Allrounder        Bowler       Bowler     Bowler       Batsman
# T-RUNS                   0           214          571        284            63
# T-WKTS                   0            18           58         31             0
# ODI-RUNS-S               0           657         1269        241            79
# ODI-SR-B               0.0         71.41        80.62      84.56         45.93
# ODI-WKTS                 0           185          288         51             0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYERNAME     130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
df[0:6]
# Out:
#    Sl.NO.    PLAYERNAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
# 5       6    Bailey, GJ    2     AUS   CSK      Batsman       0       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
# ...

# %%
df[-30:-23]
# Out:
#      Sl.NO.     PLAYERNAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 100     101     Silva, LPC    2      SL     DC      Batsman     537       1
# 101     102      Singh, RP    2     IND    DC+       Bowler     116      40
# 102     103      Smith, DR    2      WI    DC+   Allrounder     320       7
# 103     104      Smith, GC    2      SA    RR+      Batsman    8042       8
# 104     105  Sohail Tanvir    2     PAK     RR       Bowler      17       5
# 105     106   Sreesanth, S    2     IND  KXIP+       Bowler     281      87
# 106     107      Steyn, DW    2      SA   RCB+       Bowler     770     272
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 100        1587     70.40  ...  153.84       1      21     0    0.00  21.00
# 101         104     42.97  ...   68.42       1    1892    74   25.57   7.75
# 102         925     97.26  ...  148.81      24     338     9   37.56   8.14
# ...

# %%
df[-5:]
# Out:
#      Sl.NO.    PLAYERNAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 125           0      0.00  ...  125.64       2       0     0    0.00  0.00
# 126        6814     75.78  ...   42.85       0       0     0    0.00  0.00
# 127        8051     87.58  ...  131.88      67     569    23   24.74  7.02
# 128         790     73.55  ...   91.67       1    1783    65   27.43  7.75
# 129         343     95.81  ...  122.22       0      99     2   49.50  9.00
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df["PLAYERNAME"][0:10]
# Out:
# 0      Abdulla, YA
# 1     Abdur Razzak
# 2      Agarkar, AB
# 3        Ashwin, R
# 4     Badrinath, S
# 5       Bailey, GJ
# 6        Balaji, L
# 7    Bollinger, DE
# 8         Botha, J
# 9      Boucher, MV
# Name: PLAYERNAME, dtype: object

# %%
df[["PLAYERNAME","COUNTRY"]][0:10]
# Out:
#       PLAYERNAME COUNTRY
# 0    Abdulla, YA      SA
# 1   Abdur Razzak     BAN
# 2    Agarkar, AB     IND
# 3      Ashwin, R     IND
# 4   Badrinath, S     IND
# 5     Bailey, GJ     AUS
# 6      Balaji, L     IND
# 7  Bollinger, DE     AUS
# 8       Botha, J      SA
# 9    Boucher, MV      SA

# %%
df.iloc[0:5,10:12]
# Out:
#    ODI-WKTS  ODI-SR-BL
# 0         0        0.0
# 1       185       37.6
# 2       288       32.9
# 3        51       36.8
# 4         0        0.0

# %%
df.	COUNTRY.value_counts(normalize=True)
# Out:
# IND    0.407692
# AUS    0.169231
# SA     0.123077
# SL     0.092308
# PAK    0.069231
# NZ     0.053846
# WI     0.046154
# ENG    0.023077
# BAN    0.007692
# ZIM    0.007692
# Name: COUNTRY, dtype: float64

# %%
x=pd.crosstab(df["PLAYERNAME"],df["PLAYING ROLE"])
print(x)
# Out:
# PLAYING ROLE     Allrounder  Batsman  Bowler  W. Keeper
# PLAYERNAME
# Abdulla, YA               1        0       0          0
# Abdur Razzak              0        0       1          0
# Agarkar, AB               0        0       1          0
# Ashwin, R                 0        0       1          0
# Badrinath, S              0        1       0          0
# ...                     ...      ...     ...        ...
# Younis Khan               0        1       0          0
# Yuvraj Singh              0        1       0          0
# Zaheer Khan               0        0       1          0
# Zoysa, DNT                0        0       1          0
# de Villiers, AB           0        0       0          1
#
# [130 rows x 4 columns]

# %%
x.head()
# Out:
# PLAYING ROLE  Allrounder  Batsman  Bowler  W. Keeper
# PLAYERNAME
# Abdulla, YA            1        0       0          0
# Abdur Razzak           0        0       1          0
# Agarkar, AB            0        0       1          0
# Ashwin, R              0        0       1          0
# Badrinath, S           0        1       0          0

# %%
df[["PLAYERNAME","SOLD PRICE"]].sort_values("SOLD PRICE")[0:10]
# Out:
#          PLAYERNAME  SOLD PRICE
# 73       Noffke, AA       20000
# 46      Kamran Khan       24000
# 0       Abdulla, YA       50000
# 1      Abdur Razzak       50000
# 118   Van der Merwe       50000
# 5        Bailey, GJ       50000
# 85   Pomersbach, LA       50000
# 34    Henriques, MC       50000
# 61     McDonald, AB       80000
# 78     Pankaj Singh       95000

# %%
df[["PLAYERNAME","SOLD PRICE"]].sort_values("SOLD PRICE",ascending=False)[0:10]
# Out:
#         PLAYERNAME  SOLD PRICE
# 93       Sehwag, V     1800000
# 127   Yuvraj Singh     1800000
# 50        Kohli, V     1800000
# 111  Tendulkar, SR     1800000
# 113     Tiwary, SS     1600000
# 83   Pietersen, KP     1550000
# 23     Flintoff, A     1550000
# 15       Dhoni, MS     1500000
# 108     Symonds, A     1350000
# 110   Taylor, LRPL     1000000

# %%
df["PREMIUM"]=df["SOLD PRICE"]-df["BASE PRICE"]

# %%
df[["PLAYERNAME","SOLD PRICE","BASE PRICE","PREMIUM"]][0:10]
# Out:
#       PLAYERNAME  SOLD PRICE  BASE PRICE  PREMIUM
# 0    Abdulla, YA       50000       50000        0
# 1   Abdur Razzak       50000       50000        0
# 2    Agarkar, AB      350000      200000   150000
# 3      Ashwin, R      850000      100000   750000
# 4   Badrinath, S      800000      100000   700000
# 5     Bailey, GJ       50000       50000        0
# 6      Balaji, L      500000      100000   400000
# 7  Bollinger, DE      700000      200000   500000
# 8       Botha, J      950000      200000   750000
# 9    Boucher, MV      450000      200000   250000

# %%
df[["PLAYERNAME","SOLD PRICE","BASE PRICE","PREMIUM"]].sort_values("PREMIUM",ascending=False)[0:10].reset_index()
# Out:
#    index     PLAYERNAME  SOLD PRICE  BASE PRICE  PREMIUM
# 0     50       Kohli, V     1800000      150000  1650000
# 1    113     Tiwary, SS     1600000      100000  1500000
# 2    127   Yuvraj Singh     1800000      400000  1400000
# 3    111  Tendulkar, SR     1800000      400000  1400000
# 4     93      Sehwag, V     1800000      400000  1400000
# 5    108     Symonds, A     1350000      250000  1100000
# 6     15      Dhoni, MS     1500000      400000  1100000
# 7     39     Jadeja, RA      950000      100000   850000
# 8     95      Sharma, I      950000      150000   800000
# 9      3      Ashwin, R      850000      100000   750000

# %%
x=df.groupby("COUNTRY")["SOLD PRICE"].mean().reset_index()
print(x)
# Out:
#   COUNTRY    SOLD PRICE
# 0     AUS  4.340909e+05
# 1     BAN  5.000000e+04
# 2     ENG  1.066667e+06
# 3     IND  6.523396e+05
# 4      NZ  5.264286e+05
# 5     PAK  3.305556e+05
# 6      SA  4.275000e+05
# 7      SL  4.237500e+05
# 8      WI  2.791667e+05
# 9     ZIM  1.250000e+05

# %%
y=df.groupby(["COUNTRY","PLAYING ROLE"])["SOLD PRICE"].mean().reset_index()
print(y)
# Out:
#    COUNTRY PLAYING ROLE    SOLD PRICE
# 0      AUS   Allrounder  4.125000e+05
# 1      AUS      Batsman  3.333333e+05
# 2      AUS       Bowler  5.625000e+05
# 3      AUS    W. Keeper  7.000000e+05
# 4      BAN       Bowler  5.000000e+04
# 5      ENG   Allrounder  8.250000e+05
# 6      ENG      Batsman  1.550000e+06
# 7      IND   Allrounder  5.607143e+05
# 8      IND      Batsman  9.388889e+05
# 9      IND       Bowler  4.795217e+05
# 10     IND    W. Keeper  5.440000e+05
# 11      NZ   Allrounder  4.087500e+05
# 12      NZ      Batsman  6.750000e+05
# 13      NZ    W. Keeper  7.000000e+05
# 14     PAK   Allrounder  5.875000e+05
# 15     PAK      Batsman  1.625000e+05
# 16     PAK       Bowler  3.312500e+05
# 17     PAK    W. Keeper  1.500000e+05
# 18      SA   Allrounder  5.464286e+05
# 19      SA      Batsman  3.750000e+05
# 20      SA       Bowler  2.850000e+05
# 21      SA    W. Keeper  3.750000e+05
# 22      SL   Allrounder  6.000000e+05
# 23      SL      Batsman  2.875000e+05
# ...

# %%
df.groupby(["COUNTRY","PLAYING ROLE"])["SOLD PRICE"].mean().reset_index()
# Out:
#    COUNTRY PLAYING ROLE    SOLD PRICE
# 0      AUS   Allrounder  4.125000e+05
# 1      AUS      Batsman  3.333333e+05
# 2      AUS       Bowler  5.625000e+05
# 3      AUS    W. Keeper  7.000000e+05
# 4      BAN       Bowler  5.000000e+04
# 5      ENG   Allrounder  8.250000e+05
# 6      ENG      Batsman  1.550000e+06
# 7      IND   Allrounder  5.607143e+05
# 8      IND      Batsman  9.388889e+05
# 9      IND       Bowler  4.795217e+05
# 10     IND    W. Keeper  5.440000e+05
# 11      NZ   Allrounder  4.087500e+05
# 12      NZ      Batsman  6.750000e+05
# 13      NZ    W. Keeper  7.000000e+05
# 14     PAK   Allrounder  5.875000e+05
# 15     PAK      Batsman  1.625000e+05
# 16     PAK       Bowler  3.312500e+05
# 17     PAK    W. Keeper  1.500000e+05
# 18      SA   Allrounder  5.464286e+05
# 19      SA      Batsman  3.750000e+05
# 20      SA       Bowler  2.850000e+05
# 21      SA    W. Keeper  3.750000e+05
# 22      SL   Allrounder  6.000000e+05
# 23      SL      Batsman  2.875000e+05
# ...

# %%
z=y.merge(x,on="COUNTRY")
z
# Out:
#    COUNTRY PLAYING ROLE  SOLD PRICE_x  SOLD PRICE_y
# 0      AUS   Allrounder  4.125000e+05  4.340909e+05
# 1      AUS      Batsman  3.333333e+05  4.340909e+05
# 2      AUS       Bowler  5.625000e+05  4.340909e+05
# 3      AUS    W. Keeper  7.000000e+05  4.340909e+05
# 4      BAN       Bowler  5.000000e+04  5.000000e+04
# 5      ENG   Allrounder  8.250000e+05  1.066667e+06
# 6      ENG      Batsman  1.550000e+06  1.066667e+06
# 7      IND   Allrounder  5.607143e+05  6.523396e+05
# 8      IND      Batsman  9.388889e+05  6.523396e+05
# 9      IND       Bowler  4.795217e+05  6.523396e+05
# 10     IND    W. Keeper  5.440000e+05  6.523396e+05
# 11      NZ   Allrounder  4.087500e+05  5.264286e+05
# 12      NZ      Batsman  6.750000e+05  5.264286e+05
# 13      NZ    W. Keeper  7.000000e+05  5.264286e+05
# 14     PAK   Allrounder  5.875000e+05  3.305556e+05
# 15     PAK      Batsman  1.625000e+05  3.305556e+05
# 16     PAK       Bowler  3.312500e+05  3.305556e+05
# ...
