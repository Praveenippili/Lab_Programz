# %%
import matplotlib.pyplot as plt
x=[4,6,2,6,24,7,34]
plt.boxplot(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
d=pd.DataFrame(np.random.rand(10,5)*10,columns=["A","B","C","D","E"])
d.plot.box()
plt.show()

# %%
d=pd.DataFrame(np.random.rand(10)*10,columns=["A"])
d.plot(kind="box")
plt.show()
