# %%
import matplotlib.pyplot as plt
x=[10,90,40,33,88,25,26,87,65,50]
y=[23,67,43,98,56,34,98,14,6,85]
plt.scatter(x,y,s=50,marker="s",edgecolor="r")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,20,30,40,50]
s=[23,65,67,43,89]
plt.scatter(x,y,s=s)
plt.show()
